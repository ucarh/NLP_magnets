# %% [markdown]
# #### This notebook generates rather manually the QA dataset used in training the QA pipeline. There are about 1200 sentences that either mentions Tc or not. The answer is structured much like the SQUAD dataset with answer start, length of answer. We are also appending a "no-answer" at the end of each sentence and for sentences that do not mention Curie temperature, "no-answer" is picked for the answer.

# %%
import pandas as pd
import numpy as np

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df=pd.read_csv('./Curie_sentences_forQA_II_filled_in.csv')

# %%
df.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)

# %%
df[-60:-10]
# Out:
#                                        id  \
# 466        10.1016/j.jmmm.2017.06.040_1_3
# 467        10.1016/j.jmmm.2017.06.040_1_2
# 468        10.1016/j.jmmm.2017.06.040_1_1
# 469        10.1016/j.jmmm.2017.06.040_1_0
# 470        10.1016/j.jmmm.2006.10.913_4_1
# 471        10.1016/j.jmmm.2006.10.913_4_0
# 472       10.1016/j.jmmm.2006.10.913_25_1
# 473       10.1016/j.jmmm.2006.10.913_25_0
# 474    10.1016/s0304-8853(97)00863-9_13_0
# 475     10.1016/0304-8853(92)91013-j_51_0
# 476    10.1016/s0304-8853(97)00437-x_11_0
# 477       10.1016/j.jmmm.2006.10.672_26_0
# 478     10.1016/0304-8853(92)91392-7_12_1
# 479    10.1016/s0304-8853(99)00193-6_16_0
# 480        10.1016/j.jmmm.2003.10.032_3_0
# 481     10.1016/s0272-8842(02)00187-6_8_0
# 482        10.1016/j.jmmm.2015.09.018_8_2
# 483       10.1016/j.jmmm.2015.09.018_50_0
# 484       10.1016/j.jmmm.2015.09.018_60_1
# 485       10.1016/j.jmmm.2015.09.018_60_0
# 486       10.1016/j.jmmm.2015.09.018_64_0
# ...

# %%
df.loc[len(df)]=df.loc[530]
df.tail()
# Out:
#                                        id  \
# 527  10.1016/j.electacta.2014.11.052_16_5
# 528          10.1016/j.jmmm.2004.10.091_1
# 529          10.1016/j.jmmm.2004.01.084_1
# 530          10.1016/j.jmmm.2004.01.084_1
# 531          10.1016/j.jmmm.2004.01.084_1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        context  \
# ...

# %%
# idx=489
# df.loc[idx,'answer_text']="3 K"
# df.loc[idx,'answer_index']=df.loc[idx,'context'].find("3 K")

# %% [markdown]
# #### below is the manual part of finding the start index and length of the answer. it needs to be done for each record.

# %%
idx=531
question="What is the Curie temperature of LiF?"
new_id="10.1016/j.jmmm.2004.01.084_3"
df.loc[idx,'question']=question
df.loc[idx,'id']=new_id
df.loc[idx,'answer_text']=np.NaN
df.loc[idx,'answer_index']=np.NaN
# df.loc[idx,'answer_index']=df.loc[idx,'context'].find("1400K")
df.to_csv('./Curie_sentences_forQA_II_filled_in_v2.csv')
df.tail()
# Out:
#                                        id  \
# 527  10.1016/j.electacta.2014.11.052_16_5
# 528          10.1016/j.jmmm.2004.10.091_1
# 529          10.1016/j.jmmm.2004.01.084_1
# 530          10.1016/j.jmmm.2004.01.084_2
# 531          10.1016/j.jmmm.2004.01.084_3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        context  \
# ...
